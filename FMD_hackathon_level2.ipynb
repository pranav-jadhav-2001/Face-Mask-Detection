# %% [markdown]
# # **Computer Vision and Internet of Things **

# %% [markdown]
# ## **Author: Pranav jadhav**

# %% [markdown]
# ## **Task2: Detection of Face **

# %% [markdown]
#  **Download Dataset**

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1P9YgcPTZNufjC45YhtIJoGMz5Y4KtJfo' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1P9YgcPTZNufjC45YhtIJoGMz5Y4KtJfo" -O FILE && rm -rf /tmp/cookies.txt
# Out:
# --2022-05-08 18:36:58--  https://docs.google.com/uc?export=download&confirm=t&id=1P9YgcPTZNufjC45YhtIJoGMz5Y4KtJfo
# Resolving docs.google.com (docs.google.com)... 142.250.157.139, 142.250.157.100, 142.250.157.113, ...
# Connecting to docs.google.com (docs.google.com)|142.250.157.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/bftt1rr85ru1r777ncjqfgl452m1ve9h/1652034975000/13528605597967313965/*/1P9YgcPTZNufjC45YhtIJoGMz5Y4KtJfo?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2022-05-08 18:36:59--  https://doc-00-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/bftt1rr85ru1r777ncjqfgl452m1ve9h/1652034975000/13528605597967313965/*/1P9YgcPTZNufjC45YhtIJoGMz5Y4KtJfo?e=download
# Resolving doc-00-1c-docs.googleusercontent.com (doc-00-1c-docs.googleusercontent.com)... 108.177.97.132, 2404:6800:4008:c00::84
# Connecting to doc-00-1c-docs.googleusercontent.com (doc-00-1c-docs.googleusercontent.com)|108.177.97.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 158251634 (151M) [application/zip]
# Saving to: ‘FILE’
#
# FILE                100%[===================>] 150.92M  84.6MB/s    in 1.8s
#
# 2022-05-08 18:37:02 (84.6 MB/s) - ‘FILE’ saved [158251634/158251634]

# %%
# !unzip FILE
# Out:
# Archive:  FILE
#   inflating: face_detector/deploy.prototxt
#   inflating: face_detector/res10_300x300_ssd_iter_140000.caffemodel
#   inflating: mask_detector.model
#   inflating: dataset/with_mask/with_mask651.jpeg
#   inflating: dataset/with_mask/with_mask641.jpeg
#   inflating: dataset/with_mask/with_mask649.jpeg
#   inflating: dataset/with_mask/with_mask638.jpeg
#   inflating: dataset/with_mask/with_mask645.jpeg
#   inflating: dataset/with_mask/with_mask648.jpeg
#   inflating: dataset/with_mask/with_mask650.jpeg
#   inflating: dataset/with_mask/with_mask659.jpeg
#   inflating: dataset/with_mask/with_mask654.jpeg
#   inflating: dataset/with_mask/with_mask647.jpeg
#   inflating: dataset/with_mask/with_mask653.jpeg
#   inflating: dataset/with_mask/with_mask637.jpeg
#   inflating: dataset/without_mask/augmented_image_25.jpg
#   inflating: dataset/with_mask/with_mask640.jpeg
#   inflating: dataset/with_mask/with_mask644.jpeg
#   inflating: dataset/with_mask/with_mask639.jpeg
#   inflating: dataset/with_mask/with_mask636.jpeg
#   inflating: dataset/with_mask/with_mask657.jpeg
#   inflating: dataset/with_mask/with_mask656.jpeg
#   inflating: dataset/with_mask/with_mask655.jpeg
#   inflating: dataset/with_mask/with_mask483.jpg
#   inflating: dataset/with_mask/with_mask642.jpeg
#   inflating: dataset/with_mask/with_mask646.jpeg
#   inflating: dataset/with_mask/with_mask635.jpeg
#   inflating: dataset/with_mask/with_mask652.jpeg
#   inflating: dataset/without_mask/augmented_image_169.jpg
#   inflating: dataset/with_mask/with_mask658.jpeg
#   inflating: dataset/with_mask/with_mask643.jpeg
#   inflating: dataset/with_mask/with_mask470.jpg
#   inflating: dataset/with_mask/with_mask507.jpg
#   inflating: dataset/with_mask/with_mask601.jpg
#   inflating: dataset/with_mask/with_mask568.jpg
#   inflating: dataset/without_mask/augmented_image_59.jpg
#   inflating: dataset/with_mask/with_mask628.jpeg
#   inflating: dataset/without_mask/augmented_image_282.jpg
#   inflating: dataset/without_mask/augmented_image_229.jpg
#   inflating: dataset/without_mask/augmented_image_308.jpg
#   inflating: dataset/without_mask/augmented_image_37.jpg
#   inflating: dataset/without_mask/augmented_image_69.jpg
#   inflating: dataset/with_mask/with_mask564.jpg
#   inflating: dataset/without_mask/augmented_image_304.jpg
#   inflating: dataset/without_mask/augmented_image_219.jpg
#   inflating: dataset/with_mask/with_mask544.jpg
#   inflating: dataset/with_mask/with_mask508.jpg
#   inflating: dataset/without_mask/augmented_image_161.jpg
#   inflating: dataset/with_mask/with_mask559.jpg
#   inflating: dataset/without_mask/augmented_image_42.jpg
#   inflating: dataset/without_mask/augmented_image_265.jpg
#   inflating: dataset/without_mask/augmented_image_273.jpg
#   inflating: dataset/with_mask/with_mask625.jpeg
#   inflating: dataset/without_mask/augmented_image_21.jpg
#   inflating: dataset/without_mask/augmented_image_168.jpg
#   inflating: dataset/without_mask/augmented_image_199.jpg
#   inflating: dataset/without_mask/augmented_image_83.jpg
#   inflating: dataset/without_mask/augmented_image_73.jpg
#   inflating: dataset/without_mask/augmented_image_188.jpg
#   inflating: dataset/without_mask/augmented_image_2.jpg
#   inflating: dataset/without_mask/augmented_image_292.jpg
#   inflating: dataset/with_mask/with_mask515.jpg
#   inflating: dataset/without_mask/augmented_image_166.jpg
#   inflating: dataset/with_mask/with_mask552.jpg
#   inflating: dataset/with_mask/with_mask494.jpg
#   inflating: dataset/without_mask/augmented_image_64.jpg
#   inflating: dataset/with_mask/with_mask623.jpeg
#   inflating: dataset/without_mask/augmented_image_79.jpg
#   inflating: dataset/with_mask/with_mask629.jpeg
#   inflating: dataset/with_mask/with_mask577.jpg
#   inflating: dataset/with_mask/with_mask543.jpg
#   inflating: dataset/without_mask/augmented_image_221.jpg
#   inflating: dataset/without_mask/augmented_image_257.jpg
#   inflating: dataset/with_mask/with_mask474.jpg
#   inflating: dataset/with_mask/with_mask478.jpg
#   inflating: dataset/with_mask/with_mask589.jpg
#   inflating: dataset/with_mask/with_mask469.jpg
#   inflating: dataset/with_mask/with_mask537.jpg
#   inflating: dataset/with_mask/with_mask555.jpg
#   inflating: dataset/without_mask/57.jpg
#   inflating: dataset/without_mask/augmented_image_160.jpg
#   inflating: dataset/without_mask/augmented_image_154.jpg
#   inflating: dataset/with_mask/with_mask616.jpeg
#   inflating: dataset/without_mask/augmented_image_12.jpg
#   inflating: dataset/without_mask/409.jpg
#   inflating: dataset/without_mask/478.jpg
#   inflating: dataset/without_mask/augmented_image_185.jpg
#   inflating: dataset/with_mask/with_mask586.jpg
#   inflating: dataset/with_mask/with_mask389.jpg
#   inflating: dataset/without_mask/augmented_image_164.jpg
#   inflating: dataset/with_mask/with_mask354.jpg
#   inflating: dataset/without_mask/390.jpg
#   inflating: dataset/without_mask/augmented_image_109.jpg
#   inflating: dataset/with_mask/with_mask404.jpg
#   inflating: dataset/with_mask/with_mask405.jpg
#   inflating: dataset/with_mask/with_mask426.jpg
#   inflating: dataset/without_mask/453.jpg
#   inflating: dataset/with_mask/with_mask416.jpg
#   inflating: dataset/with_mask/with_mask527.jpg
#   inflating: dataset/without_mask/88.jpg
#   inflating: dataset/with_mask/with_mask293.jpg
#   inflating: dataset/with_mask/with_mask391.jpg
#   inflating: dataset/without_mask/augmented_image_106.jpg
#   inflating: dataset/without_mask/augmented_image_45.jpg
#   inflating: dataset/with_mask/with_mask407.jpg
#   inflating: dataset/without_mask/443.jpg
#   inflating: dataset/without_mask/augmented_image_290.jpg
#   inflating: dataset/without_mask/43.jpg
#   inflating: dataset/without_mask/augmented_image_149.jpg
#   inflating: dataset/without_mask/423.jpg
#   inflating: dataset/with_mask/with_mask484.jpg
#   inflating: dataset/without_mask/augmented_image_291.jpg
#   inflating: dataset/without_mask/augmented_image_30.jpg
#   inflating: dataset/with_mask/with_mask542.jpg
#   inflating: dataset/with_mask/with_mask414.jpg
#   inflating: dataset/with_mask/with_mask376.jpg
#   inflating: dataset/without_mask/augmented_image_125.jpg
#   inflating: dataset/with_mask/with_mask593.jpg
#   inflating: dataset/with_mask/with_mask499.jpg
#   inflating: dataset/with_mask/with_mask554.jpg
#   inflating: dataset/with_mask/with_mask603.jpg
#   inflating: dataset/without_mask/421.jpg
#   inflating: dataset/without_mask/augmented_image_72.jpg
#   inflating: dataset/with_mask/with_mask506.jpg
#   inflating: dataset/without_mask/augmented_image_48.jpg
#   inflating: dataset/without_mask/augmented_image_180.jpg
#   inflating: dataset/with_mask/with_mask529.jpg
#   inflating: dataset/without_mask/augmented_image_131.jpg
#   inflating: dataset/without_mask/augmented_image_18.jpg
#   inflating: dataset/without_mask/augmented_image_74.jpg
#   inflating: dataset/without_mask/augmented_image_140.jpg
#   inflating: dataset/without_mask/augmented_image_237.jpg
#   inflating: dataset/without_mask/augmented_image_174.jpg
#   inflating: dataset/with_mask/with_mask346.jpg
#   inflating: dataset/with_mask/with_mask634.jpeg
#   inflating: dataset/without_mask/augmented_image_283.jpg
#   inflating: dataset/with_mask/with_mask487.jpg
#   inflating: dataset/with_mask/with_mask352.jpg
#   inflating: dataset/without_mask/augmented_image_118.jpg
#   inflating: dataset/with_mask/with_mask513.jpg
#   inflating: dataset/without_mask/76.jpg
#   inflating: dataset/with_mask/with_mask458.jpg
#   inflating: dataset/without_mask/385.jpg
#   inflating: dataset/with_mask/with_mask509.jpg
#   inflating: dataset/without_mask/augmented_image_200.jpg
#   inflating: dataset/without_mask/augmented_image_94.jpg
#   inflating: dataset/without_mask/augmented_image_105.jpg
#   inflating: dataset/without_mask/463.jpg
#   inflating: dataset/with_mask/with_mask357.jpeg
#   inflating: dataset/with_mask/with_mask267.png
#   inflating: dataset/without_mask/388.jpg
#   inflating: dataset/without_mask/augmented_image_14.jpg
#   inflating: dataset/without_mask/349.jpg
#   inflating: dataset/without_mask/1_0_xinzi_0061.jpg
#   inflating: dataset/without_mask/282.jpg
#   inflating: dataset/without_mask/augmented_image_251.jpg
#   inflating: dataset/without_mask/214.jpg
#   inflating: dataset/without_mask/301.jpg
#   inflating: dataset/without_mask/295.jpg
#   inflating: dataset/without_mask/augmented_image_178.jpg
#   inflating: dataset/without_mask/augmented_image_97.jpg
#   inflating: dataset/with_mask/with_mask140.jpg
#   inflating: dataset/with_mask/with_mask146.jpg
#   inflating: dataset/without_mask/250.jpg
#   inflating: dataset/without_mask/augmented_image_128.jpg
#   inflating: dataset/with_mask/with_mask245.jpg
#   inflating: dataset/with_mask/with_mask397.jpg
#   inflating: dataset/with_mask/with_mask120.jpg
#   inflating: dataset/with_mask/with_mask145.jpg
#   inflating: dataset/with_mask/with_mask150.jpg
#   inflating: dataset/without_mask/augmented_image_124.jpg
#   inflating: dataset/without_mask/augmented_image_98.jpg
#   inflating: dataset/with_mask/with_mask103.jpg
#   inflating: dataset/with_mask/with_mask102.jpg
#   inflating: dataset/with_mask/with_mask329.jpg
#   inflating: dataset/with_mask/with_mask333.jpg
#   inflating: dataset/without_mask/62.jpg
#   inflating: dataset/without_mask/augmented_image_123.jpg
#   inflating: dataset/without_mask/augmented_image_165.jpg
#   inflating: dataset/without_mask/augmented_image_136.jpg
#   inflating: dataset/without_mask/420.jpg
#   inflating: dataset/without_mask/456.jpg
#   inflating: dataset/without_mask/augmented_image_246.jpg
#   inflating: dataset/with_mask/with_mask281.jpg
#   inflating: dataset/with_mask/with_mask164.jpg
#   inflating: dataset/without_mask/augmented_image_249.jpg
#   inflating: dataset/without_mask/317.jpg
#   inflating: dataset/without_mask/86.jpg
#   inflating: dataset/without_mask/augmented_image_71.jpg
#   inflating: dataset/with_mask/with_mask450.jpg
#   inflating: dataset/without_mask/augmented_image_130.jpg
#   inflating: dataset/with_mask/with_mask512.jpg
#   inflating: dataset/without_mask/91.jpg
#   inflating: dataset/with_mask/with_mask345.jpg
#   inflating: dataset/without_mask/augmented_image_111.jpg
#   inflating: dataset/with_mask/with_mask240.jpg
#   inflating: dataset/with_mask/with_mask263.jpg
#   inflating: dataset/without_mask/340.jpg
#   inflating: dataset/without_mask/362.jpg
#   inflating: dataset/with_mask/with_mask457.jpg
#   inflating: dataset/without_mask/1_0_qiwei_0049.jpg
#   inflating: dataset/with_mask/with_mask530.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0099.jpg
#   inflating: dataset/without_mask/1_0_liwen_0016.jpg
#   inflating: dataset/with_mask/with_mask064.jpg
#   inflating: dataset/with_mask/with_mask218.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0052.jpg
#   inflating: dataset/without_mask/449.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0087.jpg
#   inflating: dataset/with_mask/with_mask094.jpg
#   inflating: dataset/without_mask/1_0_luojin_0077.jpg
#   inflating: dataset/with_mask/with_mask129.jpg
#   inflating: dataset/without_mask/augmented_image_115.jpg
#   inflating: dataset/without_mask/1_0_liuruilin_0019.jpg
#   inflating: dataset/without_mask/augmented_image_112.jpg
#   inflating: dataset/without_mask/417.jpg
#   inflating: dataset/without_mask/97.jpg
#   inflating: dataset/without_mask/augmented_image_270.jpg
#   inflating: dataset/with_mask/92.jpg
#   inflating: dataset/without_mask/467.jpg
#   inflating: dataset/with_mask/85.jpg
#   inflating: dataset/without_mask/395.jpg
#   inflating: dataset/with_mask/with_mask379.jpg
#   inflating: dataset/without_mask/99.jpg
#   inflating: dataset/without_mask/1_0_lvyi_0038.jpg
#   inflating: dataset/with_mask/with_mask086.jpg
#   inflating: dataset/without_mask/336.jpg
#   inflating: dataset/with_mask/with_mask043.jpg
#   inflating: dataset/with_mask/99.jpg
#   inflating: dataset/with_mask/with_mask049.jpg
#   inflating: dataset/with_mask/35.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0128.jpg
#   inflating: dataset/without_mask/374.jpg
#   inflating: dataset/with_mask/320.jpg
#   inflating: dataset/without_mask/375.jpg
#   inflating: dataset/with_mask/with_mask398.jpg
#   inflating: dataset/with_mask/45.jpg
#   inflating: dataset/without_mask/augmented_image_163.jpg
#   inflating: dataset/with_mask/with_mask566.jpg
#   inflating: dataset/without_mask/51.jpg
#   inflating: dataset/without_mask/44.jpg
#   inflating: dataset/without_mask/augmented_image_236.jpg
#   inflating: dataset/with_mask/with_mask047.jpg
#   inflating: dataset/without_mask/augmented_image_134.jpg
#   inflating: dataset/without_mask/419.jpg
#   inflating: dataset/without_mask/237.jpg
#   inflating: dataset/without_mask/augmented_image_206.jpg
#   inflating: dataset/with_mask/with_mask384.jpg
#   inflating: dataset/without_mask/augmented_image_27.jpg
#   inflating: dataset/with_mask/with_mask583.jpg
#   inflating: dataset/with_mask/with_mask309.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0027.jpg
#   inflating: dataset/with_mask/with_mask213.jpg
#   inflating: dataset/without_mask/344.jpg
#   inflating: dataset/without_mask/1_0_liuqianhan_0049.jpg
#   inflating: dataset/without_mask/1_0_liuruilin_0017.jpg
#   inflating: dataset/without_mask/augmented_image_233.jpg
#   inflating: dataset/without_mask/augmented_image_93.jpg
#   inflating: dataset/with_mask/with_mask505.jpg
#   inflating: dataset/with_mask/with_mask032.jpg
#   inflating: dataset/without_mask/211.jpg
#   inflating: dataset/without_mask/206.jpg
#   inflating: dataset/with_mask/with_mask403.jpg
#   inflating: dataset/without_mask/1_0_xinzi_0060.jpg
#   inflating: dataset/with_mask/with_mask053.jpg
#   inflating: dataset/with_mask/with_mask558.jpg
#   inflating: dataset/with_mask/with_mask560.jpg
#   inflating: dataset/without_mask/281.jpg
#   inflating: dataset/with_mask/with_mask099.jpg
#   inflating: dataset/without_mask/1_0_zhourunfa_0128.jpg
#   inflating: dataset/without_mask/270.jpg
#   inflating: dataset/with_mask/with_mask304.jpg
#   inflating: dataset/without_mask/347.jpg
#   inflating: dataset/without_mask/368.jpg
#   inflating: dataset/without_mask/249.jpg
#   inflating: dataset/with_mask/with_mask535.jpg
#   inflating: dataset/with_mask/with_mask186.jpg
#   inflating: dataset/with_mask/with_mask013.jpg
#   inflating: dataset/without_mask/augmented_image_162.jpg
#   inflating: dataset/with_mask/with_mask224.jpg
#   inflating: dataset/with_mask/with_mask443.jpg
#   inflating: dataset/with_mask/with_mask183.jpg
#   inflating: dataset/with_mask/with_mask490.jpg
#   inflating: dataset/with_mask/with_mask291.jpg
#   inflating: dataset/with_mask/with_mask234.jpg
#   inflating: dataset/without_mask/33.jpg
#   inflating: dataset/without_mask/1_0_tianliang_0013.jpg
#   inflating: dataset/with_mask/with_mask604.jpg
#   inflating: dataset/with_mask/328.jpg
#   inflating: dataset/without_mask/augmented_image_238.jpg
#   inflating: dataset/without_mask/1_0_qiwei_0053.jpg
#   inflating: dataset/with_mask/with_mask433.png
#   inflating: dataset/with_mask/with_mask065.jpg
#   inflating: dataset/without_mask/augmented_image_143.jpg
#   inflating: dataset/without_mask/208.jpg
#   inflating: dataset/with_mask/with_mask335.jpg
#   inflating: dataset/without_mask/441.jpg
#   inflating: dataset/with_mask/30.jpg
#   inflating: dataset/without_mask/310.jpg
#   inflating: dataset/without_mask/1_0_liuruilin_0018.jpg
#   inflating: dataset/with_mask/with_mask599.jpg
#   inflating: dataset/without_mask/303.jpg
#   inflating: dataset/with_mask/with_mask029.jpg
#   inflating: dataset/with_mask/with_mask522.jpg
#   inflating: dataset/without_mask/1_0_liuqianhan_0085.jpg
#   inflating: dataset/without_mask/1_0_yangmi_0081.jpg
#   inflating: dataset/without_mask/405.jpg
#   inflating: dataset/without_mask/1_0_sunli_0010.jpg
#   inflating: dataset/with_mask/with_mask503.jpg
#   inflating: dataset/with_mask/with_mask133.jpg
#   inflating: dataset/without_mask/augmented_image_116.jpg
#   inflating: dataset/with_mask/with_mask401.jpg
#   inflating: dataset/with_mask/with_mask511.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0031.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0123.jpg
#   inflating: dataset/without_mask/23.jpg
#   inflating: dataset/with_mask/with_mask556.jpg
#   inflating: dataset/without_mask/augmented_image_192.jpg
#   inflating: dataset/with_mask/with_mask344.jpg
#   inflating: dataset/without_mask/1_0_wanghan_0022.jpg
#   inflating: dataset/with_mask/with_mask217.jpeg
#   inflating: dataset/without_mask/augmented_image_57.jpg
#   inflating: dataset/without_mask/1_0_zhouxiuna_0009.jpg
#   inflating: dataset/without_mask/269.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0094.jpg
#   inflating: dataset/with_mask/79.jpg
#   inflating: dataset/without_mask/1_0_luojin_0027.jpg
#   inflating: dataset/without_mask/1_0_liudehua_0022.jpg
#   inflating: dataset/with_mask/with_mask060.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0093.jpg
#   inflating: dataset/with_mask/33.jpg
#   inflating: dataset/without_mask/1_0_liushishi_0006.jpg
#   inflating: dataset/without_mask/1_0_lixirui_0051.jpg
#   inflating: dataset/without_mask/201.jpg
#   inflating: dataset/with_mask/with_mask315.jpg
#   inflating: dataset/with_mask/with_mask202.jpg
#   inflating: dataset/with_mask/56.jpg
#   inflating: dataset/with_mask/with_mask072.jpg
#   inflating: dataset/with_mask/331.jpg
#   inflating: dataset/without_mask/augmented_image_135.jpg
#   inflating: dataset/with_mask/with_mask042.jpg
#   inflating: dataset/with_mask/311.jpg
#   inflating: dataset/without_mask/augmented_image_235.jpg
#   inflating: dataset/without_mask/434.jpg
#   inflating: dataset/with_mask/with_mask480.jpg
#   inflating: dataset/without_mask/228.jpg
#   inflating: dataset/with_mask/342.jpg
#   inflating: dataset/without_mask/422.jpg
#   inflating: dataset/with_mask/with_mask429.jpg
#   inflating: dataset/without_mask/1_0_jiayuanyuan_0116.jpg
#   inflating: dataset/without_mask/1_0_yangmi_0140.jpg
#   inflating: dataset/with_mask/with_mask355.jpg
#   inflating: dataset/with_mask/with_mask063.jpg
#   inflating: dataset/without_mask/1_0_liwen_0006.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0066.jpg
#   inflating: dataset/without_mask/augmented_image_50.jpg
#   inflating: dataset/with_mask/with_mask366.jpg
#   inflating: dataset/without_mask/252.jpg
#   inflating: dataset/with_mask/with_mask294.jpg
#   inflating: dataset/with_mask/54.jpg
#   inflating: dataset/with_mask/with_mask154.jpg
#   inflating: dataset/without_mask/260.jpg
#   inflating: dataset/with_mask/66.jpg
#   inflating: dataset/with_mask/with_mask100.jpg
#   inflating: dataset/with_mask/with_mask476.jpg
#   inflating: dataset/with_mask/with_mask550.jpg
#   inflating: dataset/without_mask/augmented_image_224.jpg
#   inflating: dataset/with_mask/324.jpg
#   inflating: dataset/with_mask/337.jpg
#   inflating: dataset/with_mask/347.jpg
#   inflating: dataset/with_mask/with_mask321.jpg
#   inflating: dataset/with_mask/with_mask252.jpg
#   inflating: dataset/with_mask/with_mask547.jpg
#   inflating: dataset/with_mask/with_mask191.jpg
#   inflating: dataset/without_mask/239.jpg
#   inflating: dataset/without_mask/1_0_jinchen_0064.jpg
#   inflating: dataset/with_mask/with_mask261.jpg
#   inflating: dataset/without_mask/475.jpg
#   inflating: dataset/without_mask/1_0_jinchen_0011.jpg
#   inflating: dataset/with_mask/358.jpg
#   inflating: dataset/with_mask/69.jpg
#   inflating: dataset/without_mask/augmented_image_86.jpg
#   inflating: dataset/with_mask/with_mask219.jpg
#   inflating: dataset/with_mask/with_mask073.jpg
#   inflating: dataset/with_mask/with_mask190.jpg
#   inflating: dataset/without_mask/1_0_yangmi_0078.jpg
#   inflating: dataset/with_mask/with_mask194.jpg
#   inflating: dataset/with_mask/with_mask280.jpg
#   inflating: dataset/with_mask/with_mask159.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0035.jpg
#   inflating: dataset/with_mask/with_mask025.jpg
#   inflating: dataset/with_mask/with_mask461.jpg
#   inflating: dataset/with_mask/with_mask206.jpg
#   inflating: dataset/without_mask/27.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0104.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0033.jpg
#   inflating: dataset/with_mask/with_mask171.jpg
#   inflating: dataset/with_mask/with_mask288.jpg
#   inflating: dataset/without_mask/augmented_image_311.jpg
#   inflating: dataset/without_mask/1_0_zhangzhenyue_0034.jpg
#   inflating: dataset/without_mask/289.jpg
#   inflating: dataset/without_mask/451.jpg
#   inflating: dataset/with_mask/50.jpg
#   inflating: dataset/with_mask/with_mask001.jpg
#   inflating: dataset/without_mask/augmented_image_100.jpg
#   inflating: dataset/without_mask/augmented_image_234.jpg
#   inflating: dataset/with_mask/with_mask406.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0061.jpg
#   inflating: dataset/without_mask/augmented_image_172.jpg
#   inflating: dataset/with_mask/81.jpg
#   inflating: dataset/without_mask/1_0_luojin_0056.jpg
#   inflating: dataset/with_mask/with_mask343.jpg
#   inflating: dataset/with_mask/with_mask600.jpg
#   inflating: dataset/without_mask/1_0_liushishi_0097.jpg
#   inflating: dataset/without_mask/1_0_pubajia_0008.jpg
#   inflating: dataset/with_mask/353.jpg
#   inflating: dataset/with_mask/with_mask381.jpg
#   inflating: dataset/with_mask/with_mask314.jpg
#   inflating: dataset/with_mask/with_mask250.jpg
#   inflating: dataset/with_mask/with_mask034.jpg
#   inflating: dataset/with_mask/87.jpg
#   inflating: dataset/without_mask/augmented_image_150.jpg
#   inflating: dataset/with_mask/with_mask424.jpg
#   inflating: dataset/without_mask/augmented_image_240.jpg
#   inflating: dataset/with_mask/with_mask498.jpg
#   inflating: dataset/with_mask/89.jpg
#   inflating: dataset/with_mask/with_mask147.jpg
#   inflating: dataset/without_mask/1_0_pubajia_0022.jpg
#   inflating: dataset/without_mask/262.jpg
#   inflating: dataset/with_mask/316.jpg
#   inflating: dataset/without_mask/330.jpg
#   inflating: dataset/with_mask/with_mask058.jpg
#   inflating: dataset/with_mask/with_mask055.jpg
#   inflating: dataset/without_mask/1_0_qiqi_0079.jpg
#   inflating: dataset/with_mask/with_mask627.jpeg
#   inflating: dataset/with_mask/with_mask534.jpg
#   inflating: dataset/with_mask/with_mask320.jpg
#   inflating: dataset/with_mask/with_mask467.jpg
#   inflating: dataset/without_mask/425.jpg
#   inflating: dataset/with_mask/with_mask462.jpg
#   inflating: dataset/without_mask/1_0_sunhonglei_0019.jpg
#   inflating: dataset/without_mask/1_0_lixirui_0057.jpg
#   inflating: dataset/without_mask/403.jpg
#   inflating: dataset/without_mask/augmented_image_203.jpg
#   inflating: dataset/without_mask/augmented_image_319.jpg
#   inflating: dataset/with_mask/with_mask531.jpg
#   inflating: dataset/with_mask/with_mask226.jpg
#   inflating: dataset/without_mask/47.jpg
#   inflating: dataset/with_mask/with_mask124.jpg
#   inflating: dataset/without_mask/32.jpg
#   inflating: dataset/without_mask/329.jpg
#   inflating: dataset/with_mask/with_mask446.jpg
#   inflating: dataset/without_mask/455.jpg
#   inflating: dataset/without_mask/360.jpg
#   inflating: dataset/without_mask/361.jpg
#   inflating: dataset/without_mask/226.jpg
#   inflating: dataset/without_mask/augmented_image_4.jpg
#   inflating: dataset/with_mask/with_mask275.jpg
#   inflating: dataset/with_mask/with_mask310.jpg
#   inflating: dataset/without_mask/augmented_image_145.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0036.jpg
#   inflating: dataset/with_mask/with_mask087.jpg
#   inflating: dataset/without_mask/augmented_image_80.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0098.jpg
#   inflating: dataset/with_mask/with_mask338.jpg
#   inflating: dataset/without_mask/augmented_image_181.jpg
#   inflating: dataset/without_mask/53.jpg
#   inflating: dataset/without_mask/36.jpg
#   inflating: dataset/with_mask/with_mask307.jpg
#   inflating: dataset/with_mask/with_mask323.jpg
#   inflating: dataset/without_mask/1_0_liushishi_0157.jpg
#   inflating: dataset/with_mask/with_mask037.jpg
#   inflating: dataset/with_mask/with_mask015.jpg
#   inflating: dataset/with_mask/with_mask445.jpg
#   inflating: dataset/with_mask/with_mask057.jpg
#   inflating: dataset/without_mask/352.jpg
#   inflating: dataset/without_mask/1_0_liuqianhan_0050.jpg
#   inflating: dataset/without_mask/augmented_image_260.jpg
#   inflating: dataset/without_mask/augmented_image_158.jpg
#   inflating: dataset/without_mask/1_0_sunhonglei_0018.jpg
#   inflating: dataset/with_mask/with_mask021.jpg
#   inflating: dataset/with_mask/with_mask380.jpg
#   inflating: dataset/with_mask/with_mask571.jpg
#   inflating: dataset/without_mask/415.jpg
#   inflating: dataset/without_mask/440.jpg
#   inflating: dataset/without_mask/1_0_lixirui_0066.jpg
#   inflating: dataset/with_mask/with_mask580.jpg
#   inflating: dataset/with_mask/348.jpg
#   inflating: dataset/without_mask/1_0_qiqi_0005.jpg
#   inflating: dataset/without_mask/24.jpg
#   inflating: dataset/with_mask/with_mask361.jpg
#   inflating: dataset/without_mask/240.jpg
#   inflating: dataset/with_mask/306.jpg
#   inflating: dataset/with_mask/55.jpg
#   inflating: dataset/with_mask/with_mask419.jpg
#   inflating: dataset/without_mask/386.jpg
#   inflating: dataset/with_mask/with_mask153.jpeg
#   inflating: dataset/with_mask/with_mask399.jpg
#   inflating: dataset/without_mask/1_0_lixingliang_0150.jpg
#   inflating: dataset/without_mask/74.jpg
#   inflating: dataset/without_mask/397.jpg
#   inflating: dataset/with_mask/with_mask633.jpeg
#   inflating: dataset/without_mask/1_0_tianliang_0011.jpg
#   inflating: dataset/without_mask/461.jpg
#   inflating: dataset/without_mask/363.jpg
#   inflating: dataset/with_mask/with_mask035.jpg
#   inflating: dataset/with_mask/with_mask324.jpg
#   inflating: dataset/without_mask/1_0_luojin_0051.jpg
#   inflating: dataset/without_mask/1_0_liushishi_0156.jpg
#   inflating: dataset/without_mask/1_0_lixingliang_0156.jpg
#   inflating: dataset/with_mask/325.jpg
#   inflating: dataset/without_mask/248.jpg
#   inflating: dataset/without_mask/468.jpg
#   inflating: dataset/with_mask/with_mask501.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0058.jpg
#   inflating: dataset/without_mask/augmented_image_156.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0062.jpg
#   inflating: dataset/with_mask/with_mask108.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0097.jpg
#   inflating: dataset/without_mask/1_0_wanghan_0169.jpg
#   inflating: dataset/without_mask/augmented_image_95.jpg
#   inflating: dataset/without_mask/335.jpg
#   inflating: dataset/without_mask/1_0_luojin_0082.jpg
#   inflating: dataset/without_mask/416.jpg
#   inflating: dataset/with_mask/with_mask248.png
#   inflating: dataset/without_mask/1_0_qiqi_0078.jpg
#   inflating: dataset/with_mask/with_mask500.jpg
#   inflating: dataset/without_mask/augmented_image_245.jpg
#   inflating: dataset/without_mask/augmented_image_175.jpg
#   inflating: dataset/with_mask/with_mask031.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0105.jpg
#   inflating: dataset/with_mask/with_mask178.jpg
#   inflating: dataset/with_mask/with_mask131.jpg
#   inflating: dataset/with_mask/70.jpg
#   inflating: dataset/without_mask/1_0_sunhonglei_0023.jpg
#   inflating: dataset/without_mask/augmented_image_152.jpg
#   inflating: dataset/with_mask/47.jpg
#   inflating: dataset/without_mask/267.jpg
#   inflating: dataset/without_mask/augmented_image_227.jpg
#   inflating: dataset/without_mask/1_0_liushishi_0096.jpg
#   inflating: dataset/with_mask/with_mask110.jpg
#   inflating: dataset/with_mask/59.jpg
#   inflating: dataset/with_mask/330.jpg
#   inflating: dataset/with_mask/with_mask122.jpg
#   inflating: dataset/without_mask/370.jpg
#   inflating: dataset/without_mask/77.jpg
#   inflating: dataset/with_mask/with_mask269.jpg
#   inflating: dataset/without_mask/280.jpg
#   inflating: dataset/without_mask/augmented_image_44.jpg
#   inflating: dataset/without_mask/384.jpg
#   inflating: dataset/with_mask/with_mask075.jpg
#   inflating: dataset/without_mask/augmented_image_226.jpg
#   inflating: dataset/without_mask/79.jpg
#   inflating: dataset/with_mask/with_mask442.jpg
#   inflating: dataset/with_mask/with_mask242.jpg
#   inflating: dataset/without_mask/1_0_pubajia_0017.jpg
#   inflating: dataset/with_mask/with_mask010.jpg
#   inflating: dataset/with_mask/with_mask605.jpeg
#   inflating: dataset/with_mask/with_mask144.jpeg
#   inflating: dataset/with_mask/with_mask052.jpg
#   inflating: dataset/without_mask/1_0_liwen_0011.jpg
#   inflating: dataset/with_mask/301.jpg
#   inflating: dataset/without_mask/1_0_jiayuanyuan_0197.jpg
#   inflating: dataset/without_mask/augmented_image_276.jpg
#   inflating: dataset/with_mask/with_mask160.jpg
#   inflating: dataset/without_mask/204.jpg
#   inflating: dataset/with_mask/with_mask020.jpg
#   inflating: dataset/with_mask/with_mask327.jpg
#   inflating: dataset/with_mask/with_mask510.jpg
#   inflating: dataset/with_mask/57.jpg
#   inflating: dataset/with_mask/with_mask565.jpg
#   inflating: dataset/with_mask/with_mask247.jpg
#   inflating: dataset/with_mask/with_mask341.jpg
#   inflating: dataset/with_mask/with_mask468.jpg
#   inflating: dataset/with_mask/with_mask188.jpg
#   inflating: dataset/without_mask/408.jpg
#   inflating: dataset/with_mask/with_mask436.jpg
#   inflating: dataset/without_mask/1_0_wanghan_0171.jpg
#   inflating: dataset/with_mask/with_mask395.jpg
#   inflating: dataset/with_mask/with_mask425.jpg
#   inflating: dataset/with_mask/with_mask465.jpg
#   inflating: dataset/without_mask/337.jpg
#   inflating: dataset/without_mask/augmented_image_19.jpg
#   inflating: dataset/with_mask/with_mask613.jpeg
#   inflating: dataset/with_mask/299.jpg
#   inflating: dataset/with_mask/with_mask437.jpg
#   inflating: dataset/with_mask/with_mask136.jpeg
#   inflating: dataset/without_mask/312.jpg
#   inflating: dataset/without_mask/256.jpg
#   inflating: dataset/without_mask/1_0_jiayuanyuan_0047.jpg
#   inflating: dataset/without_mask/224.jpg
#   inflating: dataset/with_mask/with_mask435.jpg
#   inflating: dataset/without_mask/1_0_qiqi_0021.jpg
#   inflating: dataset/without_mask/1_0_luojin_0062.jpg
#   inflating: dataset/with_mask/88.jpg
#   inflating: dataset/without_mask/67.jpg
#   inflating: dataset/with_mask/with_mask118.jpg
#   inflating: dataset/without_mask/1_0_qiqi_0084.jpg
#   inflating: dataset/with_mask/with_mask411.jpg
#   inflating: dataset/with_mask/with_mask368.jpg
#   inflating: dataset/without_mask/augmented_image_215.jpg
#   inflating: dataset/with_mask/with_mask119.jpeg
#   inflating: dataset/without_mask/1_0_sunyue_0011.jpg
#   inflating: dataset/with_mask/with_mask024.jpg
#   inflating: dataset/without_mask/26.jpg
#   inflating: dataset/with_mask/with_mask104.jpg
#   inflating: dataset/without_mask/augmented_image_298.jpg
#   inflating: dataset/without_mask/1_0_zhouxiuna_0025.jpg
#   inflating: dataset/with_mask/341.jpg
#   inflating: dataset/without_mask/356.jpg
#   inflating: dataset/without_mask/93.jpg
#   inflating: dataset/with_mask/with_mask394.jpg
#   inflating: dataset/with_mask/with_mask286.jpg
#   inflating: dataset/without_mask/450.jpg
#   inflating: dataset/without_mask/350.jpg
#   inflating: dataset/with_mask/with_mask453.jpg
#   inflating: dataset/with_mask/with_mask615.jpeg
#   inflating: dataset/with_mask/with_mask135.jpg
#   inflating: dataset/without_mask/401.jpg
#   inflating: dataset/without_mask/augmented_image_129.jpg
#   inflating: dataset/without_mask/215.jpg
#   inflating: dataset/without_mask/1_0_sunyue_0008.jpg
#   inflating: dataset/without_mask/augmented_image_58.jpg
#   inflating: dataset/with_mask/with_mask181.jpg
#   inflating: dataset/with_mask/with_mask207.jpg
#   inflating: dataset/with_mask/with_mask538.jpg
#   inflating: dataset/without_mask/augmented_image_272.jpg
#   inflating: dataset/with_mask/with_mask393.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0069.jpg
#   inflating: dataset/with_mask/with_mask386.jpg
#   inflating: dataset/without_mask/49.jpg
#   inflating: dataset/with_mask/with_mask371.jpg
#   inflating: dataset/with_mask/with_mask517.jpg
#   inflating: dataset/with_mask/with_mask331.jpg
#   inflating: dataset/without_mask/augmented_image_293.jpg
#   inflating: dataset/without_mask/413.jpg
#   inflating: dataset/without_mask/augmented_image_137.jpg
#   inflating: dataset/with_mask/with_mask208.jpg
#   inflating: dataset/without_mask/1_0_luojin_0038.jpg
#   inflating: dataset/with_mask/with_mask364.jpg
#   inflating: dataset/without_mask/477.jpg
#   inflating: dataset/without_mask/291.jpg
#   inflating: dataset/without_mask/306.jpg
#   inflating: dataset/without_mask/1_0_lijinming_0076.jpg
#   inflating: dataset/without_mask/1_0_liushishi_0091.jpg
#   inflating: dataset/without_mask/1_0_lijinming_0094.jpg
#   inflating: dataset/with_mask/with_mask235.jpg
#   inflating: dataset/with_mask/303.jpg
#   inflating: dataset/without_mask/39.jpg
#   inflating: dataset/with_mask/40.jpg
#   inflating: dataset/without_mask/augmented_image_258.jpg
#   inflating: dataset/without_mask/1_0_liuruilin_0012.jpg
#   inflating: dataset/without_mask/augmented_image_171.jpg
#   inflating: dataset/with_mask/with_mask203.jpg
#   inflating: dataset/without_mask/1_0_qiqi_0023.jpg
#   inflating: dataset/with_mask/with_mask460.jpg
#   inflating: dataset/with_mask/with_mask592.jpg
#   inflating: dataset/with_mask/64.jpg
#   inflating: dataset/without_mask/98.jpg
#   inflating: dataset/with_mask/with_mask239.jpg
#   inflating: dataset/with_mask/with_mask432.jpg
#   inflating: dataset/without_mask/augmented_image_208.jpg
#   inflating: dataset/with_mask/with_mask009.jpg
#   inflating: dataset/without_mask/1_0_jiayuanyuan_0195.jpg
#   inflating: dataset/without_mask/augmented_image_77.jpg
#   inflating: dataset/without_mask/46.jpg
#   inflating: dataset/with_mask/with_mask496.jpg
#   inflating: dataset/with_mask/with_mask077.jpg
#   inflating: dataset/without_mask/augmented_image_262.jpg
#   inflating: dataset/with_mask/with_mask090.jpg
#   inflating: dataset/without_mask/1_0_tianliang_0014.jpg
#   inflating: dataset/without_mask/230.jpg
#   inflating: dataset/without_mask/383.jpg
#   inflating: dataset/without_mask/augmented_image_89.jpg
#   inflating: dataset/without_mask/392.jpg
#   inflating: dataset/with_mask/with_mask630.jpeg
#   inflating: dataset/with_mask/340.jpg
#   inflating: dataset/without_mask/1_0_liwen_0001.jpg
#   inflating: dataset/with_mask/with_mask085.jpg
#   inflating: dataset/with_mask/with_mask463.jpg
#   inflating: dataset/without_mask/augmented_image_70.jpg
#   inflating: dataset/with_mask/309.jpg
#   inflating: dataset/without_mask/465.jpg
#   inflating: dataset/without_mask/244.jpg
#   inflating: dataset/without_mask/259.jpg
#   inflating: dataset/with_mask/with_mask036.jpg
#   inflating: dataset/with_mask/72.jpg
#   inflating: dataset/with_mask/with_mask420.jpg
#   inflating: dataset/with_mask/with_mask168.jpg
#   inflating: dataset/with_mask/with_mask071.jpg
#   inflating: dataset/with_mask/with_mask022.jpg
#   inflating: dataset/without_mask/293.jpg
#   inflating: dataset/with_mask/with_mask027.jpg
#   inflating: dataset/with_mask/with_mask192.jpg
#   inflating: dataset/with_mask/with_mask402.jpg
#   inflating: dataset/without_mask/1_0_lixirui_0082.jpg
#   inflating: dataset/with_mask/with_mask112.jpg
#   inflating: dataset/without_mask/59.jpg
#   inflating: dataset/without_mask/30.jpg
#   inflating: dataset/without_mask/298.jpg
#   inflating: dataset/without_mask/283.jpg
#   inflating: dataset/without_mask/412.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0067.jpg
#   inflating: dataset/with_mask/with_mask111.jpg
#   inflating: dataset/with_mask/with_mask061.jpg
#   inflating: dataset/without_mask/1_0_jinchen_0072.jpg
#   inflating: dataset/without_mask/augmented_image_157.jpg
#   inflating: dataset/with_mask/1_0_3 copy 3.jpg
#   inflating: dataset/with_mask/with_mask132.jpeg
#   inflating: dataset/with_mask/with_mask008.jpg
#   inflating: dataset/with_mask/1_1_2.jpg
#   inflating: dataset/without_mask/augmented_image_62.jpg
#   inflating: dataset/with_mask/1_0_23.jpg
#   inflating: dataset/with_mask/291.jpg
#   inflating: dataset/with_mask/263.jpg
#   inflating: dataset/with_mask/with_mask244.jpg
#   inflating: dataset/with_mask/1_1_16.jpg
#   inflating: dataset/with_mask/with_mask277.jpg
#   inflating: dataset/with_mask/with_mask222.jpg
#   inflating: dataset/with_mask/1_0_29.jpg
#   inflating: dataset/with_mask/286.jpg
#   inflating: dataset/without_mask/1_0_pubajia_0018.jpg
#   inflating: dataset/with_mask/1_0_22.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0028.jpg
#   inflating: dataset/with_mask/1_0_15.jpg
#   inflating: dataset/without_mask/augmented_image_88.jpg
#   inflating: dataset/without_mask/augmented_image_315.jpg
#   inflating: dataset/with_mask/with_mask172.jpg
#   inflating: dataset/with_mask/5.jpg
#   inflating: dataset/with_mask/1_0_17.jpg
#   inflating: dataset/with_mask/with_mask163.jpg
#   inflating: dataset/with_mask/292.jpg
#   inflating: dataset/without_mask/332.jpg
#   inflating: dataset/without_mask/1_0_liuqianhan_0087.jpg
#   inflating: dataset/without_mask/52.jpg
#   inflating: dataset/with_mask/with_mask107.jpg
#   inflating: dataset/with_mask/with_mask105.jpg
#   inflating: dataset/without_mask/augmented_image_39.jpg
#   inflating: dataset/with_mask/with_mask532.jpg
#   inflating: dataset/without_mask/augmented_image_147.jpg
#   inflating: dataset/without_mask/464.jpg
#   inflating: dataset/with_mask/with_mask243.jpg
#   inflating: dataset/with_mask/with_mask095.jpeg
#   inflating: dataset/without_mask/355.jpg
#   inflating: dataset/with_mask/1_0_2 copy 8.jpg
#   inflating: dataset/with_mask/with_mask318.jpg
#   inflating: dataset/with_mask/with_mask349.jpg
#   inflating: dataset/with_mask/51.jpg
#   inflating: dataset/with_mask/73.jpg
#   inflating: dataset/without_mask/augmented_image_99.jpg
#   inflating: dataset/with_mask/1_0_9.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0124.jpg
#   inflating: dataset/with_mask/with_mask477.jpg
#   inflating: dataset/without_mask/augmented_image_177.jpg
#   inflating: dataset/with_mask/with_mask232.jpg
#   inflating: dataset/without_mask/1_0_zhouxiuna_0018.jpg
#   inflating: dataset/without_mask/1_0_yangmi_0137.jpg
#   inflating: dataset/with_mask/1_0_2 copy 5.jpg
#   inflating: dataset/with_mask/with_mask184.jpg
#   inflating: dataset/with_mask/289.jpg
#   inflating: dataset/without_mask/34.jpg
#   inflating: dataset/without_mask/1_0_jiayuanyuan_0156.jpg
#   inflating: dataset/with_mask/with_mask370.jpg
#   inflating: dataset/with_mask/276.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0076.jpg
#   inflating: dataset/without_mask/augmented_image_32.jpg
#   inflating: dataset/with_mask/with_mask175.jpg
#   inflating: dataset/with_mask/with_mask428.jpg
#   inflating: dataset/with_mask/1_0_0 copy 4.jpg
#   inflating: dataset/with_mask/168.jpg
#   inflating: dataset/with_mask/1_0_1 copy 21.jpg
#   inflating: dataset/with_mask/1_0_13 copy 2.jpg
#   inflating: dataset/with_mask/122.jpg
#   inflating: dataset/with_mask/12.jpg
#   inflating: dataset/without_mask/1_0_jiayuanyuan_0050.jpg
#   inflating: dataset/with_mask/1_0_3 2.jpg
#   inflating: dataset/with_mask/with_mask423.jpg
#   inflating: dataset/with_mask/with_mask464.jpg
#   inflating: dataset/with_mask/with_mask083.jpg
#   inflating: dataset/without_mask/augmented_image_182.jpg
#   inflating: dataset/with_mask/0_1_5.jpg
#   inflating: dataset/with_mask/1_0_1.jpeg
#   inflating: dataset/with_mask/20.jpg
#   inflating: dataset/with_mask/1_0_0 copy 12.jpg
#   inflating: dataset/with_mask/1_0_3 copy 6.jpg
#   inflating: dataset/without_mask/1_0_sunhonglei_0024.jpg
#   inflating: dataset/with_mask/295.jpg
#   inflating: dataset/with_mask/13.jpg
#   inflating: dataset/with_mask/with_mask412.jpg
#   inflating: dataset/with_mask/138.jpg
#   inflating: dataset/with_mask/1_0_4 copy.jpg
#   inflating: dataset/with_mask/1_0_75889c25ly1fjxwhpbvskj20qo140npd.jpg
#   inflating: dataset/with_mask/with_mask569.jpg
#   inflating: dataset/with_mask/with_mask528.jpg
#   inflating: dataset/without_mask/1_0_luojin_0127.jpg
#   inflating: dataset/with_mask/1_0_25.jpg
#   inflating: dataset/with_mask/with_mask130.jpg
#   inflating: dataset/with_mask/16.jpg
#   inflating: dataset/with_mask/1_0_15 copy.jpg
#   inflating: dataset/with_mask/237.jpg
#   inflating: dataset/without_mask/315.jpg
#   inflating: dataset/without_mask/augmented_image_294.jpg
#   inflating: dataset/with_mask/285.jpg
#   inflating: dataset/with_mask/1_0_ed6495a111d81158db83892aee18be01.jpg
#   inflating: dataset/without_mask/augmented_image_127.jpg
#   inflating: dataset/with_mask/254.jpg
#   inflating: dataset/with_mask/83.jpg
#   inflating: dataset/without_mask/263.jpg
#   inflating: dataset/with_mask/356.jpg
#   inflating: dataset/without_mask/1_0_qiqi_0004.jpg
#   inflating: dataset/with_mask/with_mask410.jpg
#   inflating: dataset/with_mask/31.jpg
#   inflating: dataset/without_mask/1_0_liudehua_0015.jpg
#   inflating: dataset/without_mask/augmented_image_61.jpg
#   inflating: dataset/with_mask/1_0_0 copy 9.jpg
#   inflating: dataset/without_mask/458.jpg
#   inflating: dataset/with_mask/197.jpg
#   inflating: dataset/with_mask/with_mask262.jpg
#   inflating: dataset/with_mask/0_1_8 copy.jpg
#   inflating: dataset/without_mask/augmented_image_103.jpg
#   inflating: dataset/with_mask/1_0_14.jpg
#   inflating: dataset/without_mask/augmented_image_318.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0030.jpg
#   inflating: dataset/with_mask/1_0_2.jpg
#   inflating: dataset/without_mask/augmented_image_22.jpg
#   inflating: dataset/with_mask/with_mask189.jpg
#   inflating: dataset/with_mask/1_0_1 copy 20.jpg
#   inflating: dataset/with_mask/1_0_0 copy 8.jpg
#   inflating: dataset/with_mask/1_0_2 copy 3.jpg
#   inflating: dataset/with_mask/with_mask574.jpg
#   inflating: dataset/without_mask/207.jpg
#   inflating: dataset/with_mask/137.jpg
#   inflating: dataset/with_mask/1_0_0 copy 3.jpg
#   inflating: dataset/with_mask/189.jpg
#   inflating: dataset/with_mask/270.jpg
#   inflating: dataset/with_mask/152.jpg
#   inflating: dataset/with_mask/106.jpg
#   inflating: dataset/with_mask/1_0_7 copy.jpg
#   inflating: dataset/with_mask/96.jpg
#   inflating: dataset/with_mask/60.jpg
#   inflating: dataset/with_mask/124.jpg
#   inflating: dataset/with_mask/108.jpg
#   inflating: dataset/with_mask/132.jpg
#   inflating: dataset/with_mask/1_0_1 copy 5.jpg
#   inflating: dataset/without_mask/287.jpg
#   inflating: dataset/with_mask/139.jpg
#   inflating: dataset/with_mask/with_mask372.jpg
#   inflating: dataset/with_mask/1_0_5 copy 2.jpg
#   inflating: dataset/with_mask/1_0_1 copy 17.jpg
#   inflating: dataset/with_mask/339.jpg
#   inflating: dataset/with_mask/with_mask609.jpeg
#   inflating: dataset/with_mask/with_mask311.jpg
#   inflating: dataset/with_mask/127.jpg
#   inflating: dataset/with_mask/with_mask539.jpg
#   inflating: dataset/with_mask/117.jpg
#   inflating: dataset/with_mask/with_mask268.jpg
#   inflating: dataset/with_mask/228.jpg
#   inflating: dataset/with_mask/48.jpg
#   inflating: dataset/with_mask/1_1_0.jpg
#   inflating: dataset/with_mask/241.jpg
#   inflating: dataset/with_mask/1_0_24 copy.jpg
#   inflating: dataset/without_mask/246.jpg
#   inflating: dataset/with_mask/268.jpg
#   inflating: dataset/with_mask/1_0_9 copy.jpg
#   inflating: dataset/without_mask/241.jpg
#   inflating: dataset/with_mask/272.jpg
#   inflating: dataset/with_mask/0_1_8.jpg
#   inflating: dataset/without_mask/348.jpg
#   inflating: dataset/with_mask/1_0_23 copy.jpg
#   inflating: dataset/with_mask/with_mask587.jpg
#   inflating: dataset/with_mask/1_1_663d85a4jw6dd814u9pyfj.jpg
#   inflating: dataset/with_mask/with_mask264.jpg
#   inflating: dataset/without_mask/augmented_image_244.jpg
#   inflating: dataset/with_mask/176.jpg
#   inflating: dataset/with_mask/1_0_13 copy 4.jpg
#   inflating: dataset/with_mask/with_mask187.jpg
#   inflating: dataset/with_mask/261.jpg
#   inflating: dataset/with_mask/80.jpg
#   inflating: dataset/with_mask/with_mask562.jpg
#   inflating: dataset/with_mask/203.jpg
#   inflating: dataset/without_mask/285.jpg
#   inflating: dataset/without_mask/378.jpg
#   inflating: dataset/with_mask/312.jpg
#   inflating: dataset/with_mask/170.jpg
#   inflating: dataset/with_mask/with_mask059.jpg
#   inflating: dataset/with_mask/with_mask383.png
#   inflating: dataset/without_mask/223.jpg
#   inflating: dataset/with_mask/with_mask497.jpg
#   inflating: dataset/with_mask/1_0_02d05fcb310c887fe31e5f63aa122d1e.jpg
#   inflating: dataset/without_mask/1_0_luojin_0007.jpg
#   inflating: dataset/with_mask/with_mask067.jpg
#   inflating: dataset/without_mask/augmented_image_189.jpg
#   inflating: dataset/without_mask/45.jpg
#   inflating: dataset/with_mask/182.jpg
#   inflating: dataset/with_mask/with_mask007.jpg
#   inflating: dataset/with_mask/with_mask173.jpg
#   inflating: dataset/without_mask/1_0_jiayuanyuan_0161.jpg
#   inflating: dataset/with_mask/1_0_15 copy 3.jpg
#   inflating: dataset/without_mask/1_0_liudehua_0002.jpg
#   inflating: dataset/with_mask/304.jpg
#   inflating: dataset/without_mask/432.jpg
#   inflating: dataset/with_mask/118.jpg
#   inflating: dataset/with_mask/0_2_663d85a4jw6dd814u9pyfj.jpg
#   inflating: dataset/without_mask/augmented_image_187.jpg
#   inflating: dataset/with_mask/236.jpg
#   inflating: dataset/without_mask/augmented_image_90.jpg
#   inflating: dataset/with_mask/1_0_1 copy 4.jpg
#   inflating: dataset/with_mask/58.jpg
#   inflating: dataset/with_mask/with_mask444.jpg
#   inflating: dataset/with_mask/194.jpg
#   inflating: dataset/without_mask/1_0_liudehua_0009.jpg
#   inflating: dataset/with_mask/186.jpg
#   inflating: dataset/without_mask/augmented_image_205.jpg
#   inflating: dataset/with_mask/195.jpg
#   inflating: dataset/with_mask/with_mask180.jpg
#   inflating: dataset/with_mask/0_1_3.jpg
#   inflating: dataset/with_mask/323.jpg
#   inflating: dataset/with_mask/with_mask524.jpg
#   inflating: dataset/with_mask/0_1_4 copy.jpg
#   inflating: dataset/with_mask/222.jpg
#   inflating: dataset/with_mask/101.jpg
#   inflating: dataset/with_mask/1_0_1 copy 13.jpg
#   inflating: dataset/with_mask/296.jpg
#   inflating: dataset/with_mask/with_mask028.jpg
#   inflating: dataset/with_mask/with_mask521.jpg
#   inflating: dataset/without_mask/221.jpg
#   inflating: dataset/without_mask/augmented_image_56.jpg
#   inflating: dataset/with_mask/with_mask177.jpg
#   inflating: dataset/with_mask/with_mask276.jpg
#   inflating: dataset/with_mask/1_1_0 copy.jpg
#   inflating: dataset/with_mask/with_mask570.jpg
#   inflating: dataset/with_mask/with_mask409.jpg
#   inflating: dataset/with_mask/with_mask223.jpg
#   inflating: dataset/without_mask/407.jpg
#   inflating: dataset/without_mask/augmented_image_176.jpg
#   inflating: dataset/with_mask/255.jpg
#   inflating: dataset/with_mask/1_4_16.jpg
#   inflating: dataset/with_mask/216.jpg
#   inflating: dataset/with_mask/with_mask236.jpg
#   inflating: dataset/with_mask/1_0_9de50022gy1fkizdl3o16j22kw3vcu12.jpg
#   inflating: dataset/with_mask/260.jpg
#   inflating: dataset/with_mask/1_0_13.jpg
#   inflating: dataset/without_mask/31.jpg
#   inflating: dataset/with_mask/with_mask096.jpg
#   inflating: dataset/with_mask/with_mask617.jpeg
#   inflating: dataset/with_mask/with_mask351.jpg
#   inflating: dataset/with_mask/with_mask185.jpg
#   inflating: dataset/with_mask/1_0_2 copy 2.jpg
#   inflating: dataset/with_mask/0_2_1 copy.jpg
#   inflating: dataset/with_mask/with_mask360.JPG
#   inflating: dataset/without_mask/1_0_liushishi_0004.jpg
#   inflating: dataset/with_mask/with_mask215.jpg
# ...
#   inflating: dataset/with_mask/0_0_b5ab5af2jw1evkem4w3wqj20m80xcto0.jpg
#   inflating: dataset/without_mask/402.jpg
#   inflating: dataset/without_mask/0_0_chenyao_0051.jpg
#   inflating: dataset/without_mask/1_0_anhu_0179.jpg
#   inflating: dataset/with_mask/0_0_0 copy 94.jpg
#   inflating: dataset/with_mask/with_mask573.jpg
#   inflating: dataset/without_mask/0_0_zhangbo_0064.jpg
#   inflating: dataset/without_mask/0_0_lixingliang_0013.jpg
#   inflating: dataset/with_mask/0_0_0 copy 74.jpg
#   inflating: dataset/with_mask/0_0_19 copy 5.jpg
#   inflating: dataset/without_mask/0_0_anhu_0157.jpg
#   inflating: dataset/without_mask/0_0_songzuer_0154.jpg
#   inflating: dataset/without_mask/0_0_guanyue_0040.jpg
#   inflating: dataset/without_mask/0_0_caizhuoyan_0046.jpg
#   inflating: dataset/with_mask/with_mask608.jpeg
#   inflating: dataset/without_mask/0_0_huangtingting_0010.jpg
#   inflating: dataset/with_mask/with_mask624.jpeg
#   inflating: dataset/with_mask/100.jpg
#   inflating: dataset/without_mask/0_0_zhangluyi_0051.jpg
#   inflating: dataset/without_mask/0_0_pubajia_0123.jpg
#   inflating: dataset/without_mask/151.jpg
#   inflating: dataset/without_mask/1_0_anhu_0024.jpg
#   inflating: dataset/without_mask/0_0_lixirui_0090.jpg
#   inflating: dataset/without_mask/0_0_wangdongcheng_0070.jpg
#   inflating: dataset/without_mask/0_0_lizi_0085.jpg
#   inflating: dataset/without_mask/0_0_maoxiaotong_0052.jpg
#   inflating: dataset/without_mask/0_0_linyilun_0062.jpg
#   inflating: dataset/without_mask/augmented_image_197.jpg
#   inflating: dataset/with_mask/0_0_20.jpg
#   inflating: dataset/without_mask/1_0_aidai_0072.jpg
#   inflating: dataset/without_mask/0_0_qiqi_0119.jpg
#   inflating: dataset/with_mask/with_mask561.jpg
#   inflating: dataset/without_mask/0_0_liyifeng_0051.jpg
#   inflating: dataset/without_mask/augmented_image_91.jpg
#   inflating: dataset/without_mask/0_0_lizi_0072.jpg
#   inflating: dataset/with_mask/with_mask440.jpg
#   inflating: dataset/without_mask/0_0_liuruilin_0084.jpg
#   inflating: dataset/without_mask/1_0_anhu_0111.jpg
#   inflating: dataset/with_mask/with_mask256.jpg
#   inflating: dataset/without_mask/0_0_huangtingting_0035.jpg
#   inflating: dataset/without_mask/0_0_zhouxiuna_0014.jpg
#   inflating: dataset/without_mask/1_0_liushishi_0089.jpg
#   inflating: dataset/without_mask/1_0_anhu_0140.jpg
#   inflating: dataset/with_mask/with_mask005.jpg
#   inflating: dataset/without_mask/0_0_anhu_0209.jpg
#   inflating: dataset/without_mask/augmented_image_65.jpg
#   inflating: dataset/without_mask/0_0_hanxue_0088.jpg
#   inflating: dataset/without_mask/0_0_huangjinglun_0010.jpg
#   inflating: dataset/with_mask/0_1_7 copy.jpg
#   inflating: dataset/without_mask/136.jpg
#   inflating: dataset/without_mask/0_0_caizhuoyan_0027.jpg
#   inflating: dataset/without_mask/0_0_yangmi_0038.jpg
#   inflating: dataset/without_mask/1_0_aidai_0149.jpg
#   inflating: dataset/without_mask/0_0_licaihua_0031.jpg
#   inflating: dataset/without_mask/0_0_cengyongti_0037.jpg
#   inflating: dataset/without_mask/0_0_hanxue_0010.jpg
#   inflating: dataset/without_mask/0_0_masu_0081.jpg
#   inflating: dataset/without_mask/1_0_aidai_0104.jpg
#   inflating: dataset/without_mask/131.jpg
#   inflating: dataset/with_mask/0_1_74b0deabjw1f8hqhmjh63j21kw23u1kx.jpg
#   inflating: dataset/without_mask/0_0_maolinlin_0070.jpg
#   inflating: dataset/without_mask/0_0_gulinazha_0149.jpg
#   inflating: dataset/without_mask/1_0_zhouxiuna_0010.jpg
#   inflating: dataset/with_mask/274.jpg
#   inflating: dataset/with_mask/0_0_10 copy 13.jpg
#   inflating: dataset/without_mask/1_0_jinchen_0065.jpg
#   inflating: dataset/with_mask/1_0_1 copy 3.jpg
#   inflating: dataset/without_mask/1_0_luojin_0001.jpg
#   inflating: dataset/without_mask/0_0_xuhao_0015.jpg
#   inflating: dataset/without_mask/0_0_yuanshanshan_0022.jpg
#   inflating: dataset/with_mask/with_mask431.JPG
#   inflating: dataset/without_mask/0_0_cengyongti_0091.jpg
#   inflating: dataset/without_mask/1_0_aidai_0099.jpg
#   inflating: dataset/without_mask/1_0_aidai_0180.jpg
#   inflating: dataset/without_mask/0_0_chenhuilin_0076.jpg
#   inflating: dataset/with_mask/with_mask382.jpg
#   inflating: dataset/without_mask/0_0_shaofeng_0014.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0034.jpg
#   inflating: dataset/without_mask/1_0_baibaihe_0057.jpg
#   inflating: dataset/without_mask/1_0_aidai_0127.jpg
#   inflating: dataset/without_mask/0_0_huxia_0121.jpg
#   inflating: dataset/without_mask/0_0_baobeier_0098.jpg
#   inflating: dataset/with_mask/with_mask631.jpeg
#   inflating: dataset/without_mask/1_0_aidai_0112.jpg
#   inflating: dataset/without_mask/0_0_pubajia_0002.jpg
#   inflating: dataset/without_mask/0_0_lijinming_0045.jpg
#   inflating: dataset/without_mask/0_0_lijinming_0072.jpg
#   inflating: dataset/without_mask/1_0_anhu_0107.jpg
#   inflating: dataset/without_mask/163.jpg
#   inflating: dataset/without_mask/0_0_raowei_0042.jpg
#   inflating: dataset/without_mask/0_0_jianailiang_0024.jpg
#   inflating: dataset/with_mask/with_mask563.jpg
#   inflating: dataset/without_mask/0_0_tanjing_0031.jpg
#   inflating: dataset/without_mask/1_0_aidai_0125.jpg
#   inflating: dataset/without_mask/0_0_liyapeng_0028.jpg
#   inflating: dataset/without_mask/16.jpg
#   inflating: dataset/with_mask/0_0_16 copy.jpg
#   inflating: dataset/without_mask/1_0_nieyuan_0092.jpg
#   inflating: dataset/with_mask/with_mask014.png
#   inflating: dataset/without_mask/0_0_haiqing_0173.jpg
#   inflating: dataset/without_mask/0_0_jingbairan_0019.jpg
#   inflating: dataset/with_mask/0_0_006BAfOegy1fu6po8jzzxj30zk1hc4lj.jpg
#   inflating: dataset/without_mask/63.jpg
#   inflating: dataset/without_mask/0_0_fanshiqi_0089.jpg
#   inflating: dataset/without_mask/1_0_liuqianhan_0091.jpg
#   inflating: dataset/without_mask/1_0_aidai_0126.jpg
#   inflating: dataset/without_mask/0_0_maoxiaotong_0060.jpg
#   inflating: dataset/without_mask/0_0_anhu_0211.jpg
#   inflating: dataset/without_mask/175.jpg
#   inflating: dataset/with_mask/0_1_1 copy 2.jpg
#   inflating: dataset/without_mask/1_0_lixirui_0058.jpg
#   inflating: dataset/with_mask/0_0_7 copy 19.jpg
#   inflating: dataset/with_mask/1_0_1 copy 12.jpg
#   inflating: dataset/without_mask/1_0_qiqi_0029.jpg
#   inflating: dataset/with_mask/with_mask557.jpg
#   inflating: dataset/with_mask/41.jpg
#   inflating: dataset/without_mask/0_0_lijian_0054.jpg
#   inflating: dataset/with_mask/157.jpg
#   inflating: dataset/with_mask/0_0_1 copy 7.jpg
#   inflating: dataset/with_mask/338.jpg
#   inflating: dataset/with_mask/0_1_18.jpg
#   inflating: dataset/without_mask/1_0_aidai_0009.jpg
#   inflating: dataset/without_mask/84.jpg
#   inflating: dataset/without_mask/0_0_qiuze_0095.jpg
#   inflating: dataset/without_mask/1_0_anhu_0008.jpg
#   inflating: dataset/without_mask/1_0_anhu_0229.jpg
#   inflating: dataset/with_mask/with_mask350.jpg
#   inflating: dataset/without_mask/186.jpg
#   inflating: dataset/without_mask/0_0_yingzi_0030.jpg
#   inflating: dataset/without_mask/0_0_qiwei_0081.jpg
#   inflating: dataset/without_mask/0_0_songzuer_0084.jpg
#   inflating: dataset/with_mask/0_0_9 copy 4.jpg
#   inflating: dataset/without_mask/0_0_xinzi_0265.jpg
#   inflating: dataset/with_mask/with_mask113.jpg
#   inflating: dataset/with_mask/0_0_1 copy 21.jpg
#   inflating: dataset/without_mask/0_0_zhaoyazhi_0063.jpg
#   inflating: dataset/without_mask/0_0_sunyizhou_0059.jpg
#   inflating: dataset/without_mask/0_0_fanyichen_0011.jpg
#   inflating: dataset/without_mask/0_0_sunhonglei_0114.jpg
#   inflating: dataset/with_mask/288.jpg
#   inflating: dataset/with_mask/329.jpg
#   inflating: dataset/with_mask/0_0_49.jpg
#   inflating: dataset/without_mask/0_0_liuqianhan_0067.jpg
#   inflating: dataset/without_mask/1_0_aidai_0060.jpg
#   inflating: dataset/without_mask/0_0_anhu_0214.jpg
#   inflating: dataset/with_mask/0_0_6 copy 13.jpg
#   inflating: dataset/with_mask/with_mask518.jpg
#   inflating: dataset/without_mask/0_0_chenhaomin_0053.jpg
#   inflating: dataset/without_mask/0_0_jiayuanyuan_0175.jpg
#   inflating: dataset/without_mask/0_0_pubajia_0083.jpg
#   inflating: dataset/without_mask/1_0_aidai_0024.jpg
#   inflating: dataset/with_mask/0_0_≈˙◊¢ 2020-02-24 220536.png
#   inflating: dataset/without_mask/0_0_tianliang_0019.jpg
#   inflating: dataset/without_mask/137.jpg
#   inflating: dataset/with_mask/0_0_0 copy 95.jpg
#   inflating: dataset/without_mask/0_0_nieyuan_0170.jpg
#   inflating: dataset/without_mask/0_0_cengyongti_0058.jpg
#   inflating: dataset/with_mask/0_0_2 copy 25.jpg
#   inflating: dataset/with_mask/0_1_4 copy 2.jpg
#   inflating: dataset/with_mask/0_0_12.jpg
#   inflating: dataset/with_mask/302.jpg
#   inflating: dataset/without_mask/1_0_anhu_0035.jpg
#   inflating: dataset/with_mask/0_0_œ¬‘ÿ.png
#   inflating: dataset/with_mask/with_mask390.jpg
#   inflating: dataset/without_mask/0_0_guanyue_0072.jpg
#   inflating: dataset/without_mask/0_0_lijinming_0048.jpg
#   inflating: dataset/without_mask/0_0_fanyichen_0029.jpg
#   inflating: dataset/without_mask/0_0_caiguoqing_0130.jpg
#   inflating: dataset/with_mask/332.jpg
#   inflating: dataset/with_mask/220.jpg
#   inflating: dataset/without_mask/0_0_benxi_0129.jpg
#   inflating: dataset/with_mask/0_0_ab41fce2gy1fyq9sp8l7rj223u35sx6p.jpg
#   inflating: dataset/with_mask/0_0_2.jpg
#   inflating: dataset/without_mask/0_0_liuqianhan_0042.jpg
#   inflating: dataset/without_mask/0_0_nieyuan_0186.jpg
#   inflating: dataset/without_mask/1_0_lijinming_0095.jpg
#   inflating: dataset/with_mask/0_0_13 copy 6.jpg
#   inflating: dataset/with_mask/with_mask002.jpg
#   inflating: dataset/without_mask/augmented_image_117.jpg
#   inflating: dataset/without_mask/0_0_huge_0019.jpg
#   inflating: dataset/without_mask/0_0_liushishi_0039.jpg
#   inflating: dataset/without_mask/0_0_qiuze_0141.jpg
#   inflating: dataset/without_mask/0_0_lixingliang_0037.jpg
#   inflating: dataset/with_mask/0_0_3 copy 19.jpg
#   inflating: dataset/with_mask/1_0_2 copy 6.jpg
#   inflating: dataset/without_mask/0_0_masu_0084.jpg
#   inflating: dataset/without_mask/1_0_aidai_0004.jpg
#   inflating: dataset/without_mask/149.jpg
#   inflating: dataset/with_mask/0_1_43.jpg
#   inflating: dataset/without_mask/0_0_baobeier_0140.jpg
#   inflating: dataset/without_mask/0_0_liuqianhan_0060.jpg
#   inflating: dataset/without_mask/0_0_yaochen_0037.jpg
#   inflating: dataset/without_mask/0_0_jinchen_0120.jpg
#   inflating: dataset/without_mask/0_0_chenyao_0024.jpg
#   inflating: dataset/without_mask/0_0_guanyue_0010.jpg
#   inflating: dataset/without_mask/127.jpg
#   inflating: dataset/without_mask/0_0_anhu_0189.jpg
#   inflating: dataset/without_mask/0_0_liushishi_0072.jpg
#   inflating: dataset/without_mask/64.jpg
#   inflating: dataset/with_mask/with_mask452.jpg
#   inflating: dataset/without_mask/184.jpg
#   inflating: dataset/without_mask/0_0_linyilun_0073.jpg
#   inflating: dataset/without_mask/0_0_zhangluyi_0082.jpg
#   inflating: dataset/without_mask/452.jpg
#   inflating: dataset/without_mask/0_0_chenxiang_0071.jpg
#   inflating: dataset/without_mask/0_0_sunhonglei_0064.jpg
#   inflating: dataset/without_mask/0_0_sunli_0232.jpg
#   inflating: dataset/with_mask/0_0_15 copy 6.jpg
#   inflating: dataset/without_mask/1_0_aidai_0138.jpg
#   inflating: dataset/without_mask/0_0_likeqin_0146.jpg
#   inflating: dataset/without_mask/0_0_lanxi_0037.jpg
#   inflating: dataset/without_mask/0_0_wukequn_0019.jpg
#   inflating: dataset/without_mask/0_0_songzuer_0079.jpg
#   inflating: dataset/without_mask/0_0_sunli_0104.jpg
#   inflating: dataset/without_mask/0_0_wangdongcheng_0089.jpg
#   inflating: dataset/without_mask/augmented_image_173.jpg
#   inflating: dataset/without_mask/0_0_huge_0039.jpg
#   inflating: dataset/without_mask/0_0_liuqianhan_0208.jpg
#   inflating: dataset/without_mask/1_0_anhu_0185.jpg
#   inflating: dataset/with_mask/0_0_1 copy 5.jpg
#   inflating: dataset/with_mask/0_0_1 copy 10.jpg
#   inflating: dataset/without_mask/0_0_jinchen_0082.jpg
#   inflating: dataset/without_mask/1_0_anhu_0065.jpg
#   inflating: dataset/with_mask/42.jpg
#   inflating: dataset/without_mask/0_0_liuruilin_0101.jpg
#   inflating: dataset/without_mask/1_0_qiwei_0052.jpg
#   inflating: dataset/without_mask/0_0_yangmi_0018.jpg
#   inflating: dataset/with_mask/103.jpg
#   inflating: dataset/with_mask/0_0_16 copy 8.jpg
#   inflating: dataset/without_mask/117.jpg
#   inflating: dataset/without_mask/1_0_anhu_0137.jpg
#   inflating: dataset/without_mask/0_0_wangruoyi_0114.jpg
#   inflating: dataset/without_mask/augmented_image_119.jpg
#   inflating: dataset/without_mask/0.jpg
#   inflating: dataset/with_mask/0_0_14 copy 2.jpg
#   inflating: dataset/with_mask/0_0_0 copy 78.jpg
#   inflating: dataset/with_mask/0_0_7 copy.jpg
#   inflating: dataset/without_mask/0_0_caiguoqing_0146.jpg
#   inflating: dataset/without_mask/1_0_lixingliang_0008.jpg
#   inflating: dataset/with_mask/0_1_4.jpg
#   inflating: dataset/without_mask/1_0_anhu_0088.jpg
#   inflating: dataset/without_mask/0_0_sunli_0120.jpg
#   inflating: dataset/without_mask/469.jpg
#   inflating: dataset/without_mask/0_0_maoxiaotong_0167.jpg
#   inflating: dataset/with_mask/0_0_8bf8364ed98ac9cbeb3c45e87270b886.jpeg
#   inflating: dataset/with_mask/0_0_11 copy 4.jpg
#   inflating: dataset/without_mask/0_0_hanxue_0004.jpg
#   inflating: dataset/without_mask/1_0_anhu_0079.jpg
#   inflating: dataset/without_mask/0_0_chenhuilin_0018.jpg
#   inflating: dataset/without_mask/1_0_chenyao_0020.jpg
#   inflating: dataset/without_mask/0_0_xuhao_0002.jpg
#   inflating: dataset/with_mask/1_0_20.jpg
#   inflating: dataset/with_mask/0_0_≈˙◊¢ 2020-02-24 222124.png
#   inflating: dataset/with_mask/174.jpg
#   inflating: dataset/with_mask/1_0_25 copy.jpg
#   inflating: dataset/without_mask/0_0_raowei_0014.jpg
#   inflating: dataset/with_mask/0_0_1 copy 12.jpg
#   inflating: dataset/without_mask/0_0_gulinazha_0078.jpg
#   inflating: dataset/without_mask/326.jpg
#   inflating: dataset/without_mask/4.jpg
#   inflating: dataset/without_mask/1_0_lixingliang_0010.jpg
#   inflating: dataset/without_mask/0_0_baobeier_0014.jpg
#   inflating: dataset/with_mask/with_mask161.png
#   inflating: dataset/with_mask/0_0_27 copy.jpg
#   inflating: dataset/with_mask/25.jpg
#   inflating: dataset/with_mask/with_mask485.jpg
#   inflating: dataset/without_mask/0_0_zhangrui_0035.jpg
#   inflating: dataset/without_mask/1_0_luojin_0111.jpg
#   inflating: dataset/with_mask/0_0_6 copy 16.jpg
#   inflating: dataset/without_mask/1_0_liuruilin_0024.jpg
#   inflating: dataset/without_mask/1_0_liushishi_0158.jpg
#   inflating: dataset/with_mask/0_0_6 copy 6.jpg
#   inflating: dataset/without_mask/1_0_aidai_0150.jpg
#   inflating: dataset/with_mask/with_mask582.jpg
#   inflating: dataset/without_mask/augmented_image_33.jpg
#   inflating: dataset/with_mask/with_mask549.jpg
#   inflating: dataset/with_mask/188.jpg
#   inflating: dataset/with_mask/0_0_1 copy 31.jpg
#   inflating: dataset/with_mask/with_mask299.jpg
#   inflating: dataset/with_mask/0_0_24 copy 7.jpg
#   inflating: dataset/with_mask/0_0_5 copy 25.jpg
#   inflating: dataset/with_mask/with_mask298.jpg
#   inflating: dataset/with_mask/with_mask612.jpeg
#   inflating: dataset/with_mask/with_mask266.jpg
#   inflating: dataset/without_mask/1_0_huxia_0060.jpg
#   inflating: dataset/with_mask/with_mask362.jpg
#   inflating: dataset/without_mask/323.jpg
#   inflating: dataset/with_mask/with_mask358.jpg
#   inflating: dataset/with_mask/with_mask493.jpg
#   inflating: dataset/without_mask/1_0_hanxue_0120.jpg
#   inflating: dataset/with_mask/180.jpg
#   inflating: dataset/with_mask/1_0_21.jpg
#   inflating: dataset/with_mask/0_0_3 copy.jpg
#   inflating: dataset/without_mask/augmented_image_54.jpg
#   inflating: dataset/with_mask/0_0_0 copy 10.jpg
#   inflating: dataset/with_mask/with_mask155.jpg
#   inflating: dataset/without_mask/1_0_jiayuanyuan_0150.jpg
#   inflating: dataset/with_mask/0_0_0 copy 56.jpg

# %% [markdown]
# **Import Libraries**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import imutils
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import os
import cv2
from google.colab.patches import cv2_imshow
from imutils.video import VideoStream
import time
import sys

# %% [markdown]
# **Import Model**

# %%
#Setting path to configuration file
prototxtPath = os.path.sep.join(["face_detector", "deploy.prototxt"])

#setting path to weights
weightsPath = os.path.sep.join(["face_detector",
	"res10_300x300_ssd_iter_140000.caffemodel"])

#Creating the network to detect faces
net = cv2.dnn.readNet(prototxtPath, weightsPath)

# %% [markdown]
# **Training**

# %%
imagePaths = list(paths.list_images("dataset"))
data = []
labels = []

# loop over the image paths
for imagePath in imagePaths:
	# extract the class label from the filename
	label = imagePath.split(os.path.sep)[-2]

	# load the input image (224x224) and preprocess it
	image = load_img(imagePath, target_size=(224, 224))
	image = img_to_array(image)
	image = preprocess_input(image)

	# update the data and labels lists, respectively
	data.append(image)
	labels.append(label)
 
data = np.array(data, dtype="float32")
labels = np.array(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

# %% [markdown]
# **Create Model**

# %%
baseModel = MobileNetV2(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(224, 224, 3)))

# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)

# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in baseModel.layers:
	layer.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
LR = 1e-4     #learning rate
EPOCHS = 10    #no. of epochs
BS = 32       #batch size

#We will use Adam Optimizer for our model
opt= Adam(lr=LR, decay=LR / EPOCHS)

#To compile the model we use 'binary crossentropy' as loss function and set the metrics to accuracy
model.compile(loss="binary_crossentropy", optimizer=opt,
metrics=["accuracy"])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
aug = ImageDataGenerator(
	rotation_range=20,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest")

# %%
H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS)
# Out:
# Epoch 1/10
# 10/95 [==>...........................] - ETA: 1:38 - loss: 0.7121 - accuracy: 0.6250

# %%
preds = model.evaluate(testX, testY)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))

# %%
model.save("model", save_format="h5")

# %% [markdown]
# **Detection on Image**

# %%
model = load_model("model")

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

# %%
def take_photo(filename='/content/photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
image_file = take_photo()

# %%
image = cv2.imread(image_file)

# resize it to have a maximum width of 400 pixels
image = imutils.resize(image, width=400)
(h, w) = image.shape[:2]
print(w,h)
cv2_imshow(image)

# %%
image = imutils.resize(image, width=400)
blob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0))

# %%
net.setInput(blob)
detections = net.forward()

# %%
for i in range(0, detections.shape[2]):
	# extract the confidence (i.e., probability) associated with
	# the detection
	confidence = detections[0, 0, i, 2]

	# filter. out weak detections by ensuring the confidence is
	# greater than the minimum confidence
	if confidence > 0.5:
		# compute the (x, y)-coordinates of the bounding box for
		# the object
		box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
		(startX, startY, endX, endY) = box.astype("int")

		# ensure the bounding boxes fall within the dimensions of
		# the frame
		(startX, startY) = (max(0, startX), max(0, startY))
		(endX, endY) = (min(w - 1, endX), min(h - 1, endY))

		# extract the face ROI, convert it from BGR to RGB channel
		# ordering, resize it to 224x224, and preprocess it
		face = image[startY:endY, startX:endX]
		face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
		face = cv2.resize(face, (224, 224))
		face = img_to_array(face)
		face = preprocess_input(face)
		face = np.expand_dims(face, axis=0)

		# pass the face through the model to determine if the face
		# has a mask or not
		(mask, withoutMask) = model.predict(face)[0]

		# determine the class label and color we'll use to draw
		# the bounding box and text
		label = "Mask" if mask > withoutMask else "No Mask"
		color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

		# include the probability in the label
		label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

		# display the label and bounding box rectangle on the output
		# frame
		cv2.putText(image, label, (startX, startY - 10),
			cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
		cv2.rectangle(image, (startX, startY), (endX, endY), color, 2)

# %%
cv2_imshow(image)

# %%
# !pip install ffmpeg-python

# %%
import io
import ffmpeg
from IPython.display import HTML
import PIL
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from base64 import b64decode, b64encode

# %%
def detect_and_predict_mask(frame, faceNet, maskNet):
	# grab the dimensions of the frame and then construct a blob
	# from it
	(h, w) = frame.shape[:2]
	blob = cv2.dnn.blobFromImage(frame, 1.0, (300, 300),
		(104.0, 177.0, 123.0))

	# pass the blob through the network and obtain the face detections
	faceNet.setInput(blob)
	detections = faceNet.forward()

	# initialize our list of faces, their corresponding locations,
	# and the list of predictions from our face mask network
	faces = []
	locs = []
	preds = []

	# loop over the detections
	for i in range(0, detections.shape[2]):
		# extract the confidence (i.e., probability) associated with
		# the detection
		confidence = detections[0, 0, i, 2]

		# filter out weak detections by ensuring the confidence is
		# greater than the minimum confidence
		if confidence > 0.5:
			# compute the (x, y)-coordinates of the bounding box for
			# the object
			box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
			(startX, startY, endX, endY) = box.astype("int")

			# ensure the bounding boxes fall within the dimensions of
			# the frame
			(startX, startY) = (max(0, startX), max(0, startY))
			(endX, endY) = (min(w - 1, endX), min(h - 1, endY))

			# extract the face ROI, convert it from BGR to RGB channel
			# ordering, resize it to 224x224, and preprocess it
			face = frame[startY:endY, startX:endX]
			face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
			face = cv2.resize(face, (224, 224))
			face = img_to_array(face)
			face = preprocess_input(face)

			# add the face and bounding boxes to their respective
			# lists
			faces.append(face)
			locs.append((startX, startY, endX, endY))

	# only make a predictions if at least one face was detected
	if len(faces) > 0:
		# for faster inference we'll make batch predictions on *all*
		# faces at the same time rather than one-by-one predictions
		# in the above `for` loop
		faces = np.array(faces, dtype="float32")
		preds = maskNet.predict(faces, batch_size=32)
  # return a 2-tuple of the face locations and their corresponding
	# locations
	return (locs, preds)

# %%
maskNet = load_model("model")

# %%
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)

def video_frame(label_html, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data


def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array) # numpy array into PIL image object
  iobuf = io.BytesIO()
  
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')

  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''
count = 0 
while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break
    

    # convert JS response to OpenCV Image
    image = js_to_image(js_reply["img"])
    v=True
    if v == True:
      frame = imutils.resize(image, width=400)
    (locs, preds) = detect_and_predict_mask(frame, net, maskNet)
    for (box, pred) in zip(locs, preds):


		# unpack the bounding box and predictions
      (startX, startY, endX, endY) = box
      (mask, withoutMask) = pred

		# determine the class label and color we'll use to draw
		# the bounding box and text
      label = "Mask" if mask > withoutMask else "No Mask"
      color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

		# include the probability in the label
      label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

		# display the label and bounding box rectangle on the output
		# frame
      frame=cv2.putText(frame, label, (startX, startY - 10),cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
      frame=cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)
    cv2_imshow(frame)
